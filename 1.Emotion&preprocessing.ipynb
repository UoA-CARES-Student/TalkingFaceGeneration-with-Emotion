# %% [markdown]
# **Emotional talking face Generator**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/final_p4p
# Out:
# /content/gdrive/MyDrive/final_p4p

# %%
# !git clone https://github.com/UoA-CARES-Student/TalkingFaceGeneration-with-Emotion.git
# !cd TalkingFaceGeneration-with-Emotion && git fetch
# Out:
# Cloning into 'TalkingFaceGeneration-with-Emotion'...
# remote: Enumerating objects: 1390, done.
# remote: Counting objects: 100% (387/387), done.
# remote: Compressing objects: 100% (332/332), done.
# remote: Total 1390 (delta 81), reused 339 (delta 55), pack-reused 1003
# Receiving objects: 100% (1390/1390), 472.70 MiB | 15.61 MiB/s, done.
# Resolving deltas: 100% (326/326), done.
# Updating files: 100% (121/121), done.

# %%
# !cd TalkingFaceGeneration-with-Emotion && git checkout -f 2023_all_together
# Out:
# Updating files: 100% (751/751), done.
# Branch '2023_all_together' set up to track remote branch '2023_all_together' from 'origin'.
# Switched to a new branch '2023_all_together'

# %%
# %cd TalkingFaceGeneration-with-Emotion/Emotion
# Out:
# /content/gdrive/MyDrive/final_p4p/TalkingFaceGeneration-with-Emotion/Emotion

# %%
# !gdown https://drive.google.com/uc?id=1xiKfABPX0heyTKvrTBnWTmix2e7KB5rJ&export=download
# !unzip model.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xiKfABPX0heyTKvrTBnWTmix2e7KB5rJ
# To: /content/gdrive/MyDrive/final_p4p/TalkingFaceGeneration-with-Emotion/Emotion/model.zip
# 100% 154M/154M [00:03<00:00, 46.6MB/s]
# Archive:  model.zip
#   inflating: model/args.txt
#   inflating: model/generator.pt

# %%
# %cd ../CodeFormer
# Out:
# /content/gdrive/MyDrive/final_p4p/TalkingFaceGeneration-with-Emotion/CodeFormer

# %%
# !python basicsr/setup.py develop
# Out:
# /usr/local/lib/python3.10/dist-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running develop
# /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
# ...

# %%
cd ../Emotion
# Out:
# /content/gdrive/MyDrive/final_p4p/TalkingFaceGeneration-with-Emotion/Emotion

# %%
# !python -m pip install visdom
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408194 sha256=76a599277e02eaa5dcc4abaae308036cd2a181ab3039ab8c4849286aa9b19c21
#   Stored in directory: /root/.cache/pip/wheels/42/29/49/5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
# Successfully built visdom
# ...

# %%
# !python generate_emotion.py -im ./data/image_samples/resize_Anne.jpg -is ./data/speech_samples/speech01.wav -m ./model/
# Out:
# tensor([[1., 0., 0., 0., 0., 0.]])
# (63, 128, 128, 3) True
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
